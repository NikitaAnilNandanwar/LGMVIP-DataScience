# %% [markdown]
# <h1> LetsGrowMore(LGMVIPFEB2022) </h1>
# <h2> Author Name - Nikita Anil Nandanwar </h2>
# <h2> Task4 - Image to Pencil Sketch with Python </h2>
# <h2> Level - Beginner </h2>
# <h2> Language - Python </h2>

# %% [markdown]
# ## Importing required Libraries

# %%
import cv2
import numpy as np
from PIL import Image
from IPython.display import display

# %%
image = cv2.imread('image.jpeg')
# cv2.imshow("Original Image", image)
# cv2.waitKey(0)
image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
display(Image.fromarray(image))
# Out:
# <PIL.Image.Image image mode=RGB size=400x300 at 0x2CCC87C4B80>

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
display(Image.fromarray(gray_image))
# Out:
# <PIL.Image.Image image mode=L size=400x300 at 0x2CCB78BCD60>

# %%
inverted_image = cv2.bitwise_not(gray_image)
display(Image.fromarray(inverted_image))
# Out:
# <PIL.Image.Image image mode=L size=400x300 at 0x2CCB8D1A6A0>

# %%
blurred_image = cv2.GaussianBlur(inverted_image, (21, 21), 0)
display(Image.fromarray(blurred_image))
# Out:
# <PIL.Image.Image image mode=L size=400x300 at 0x2CCB78BCF40>

# %%
inverted_blurred = cv2.bitwise_not(blurred_image)
pencil_sketch = cv2.divide(gray_image, inverted_blurred, scale=256.0)
display(Image.fromarray(pencil_sketch))
# Out:
# <PIL.Image.Image image mode=L size=400x300 at 0x2CCB78BCD00>
